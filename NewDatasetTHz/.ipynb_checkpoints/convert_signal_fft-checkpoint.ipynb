# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from PIL import Image
import rampy
from BaselineRemoval import BaselineRemoval
# %matplotlib inline
# %config InlineBackend.figure_fornat = 'retina'
pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',5000)

# %% [markdown]
# # Rh07Run01

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run01_Rh7_0/'
filenames = glob.glob(path + "td*.csv")

dfs_Run01 = []
for file in filenames:
    dfs_Run01.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh07R01 = []
for i in np.arange(0,len(dfs_Run01),1):
    num = dfs_Run01[i]['Data'].to_numpy()
    signal_Rh07R01.append(num)

# %%
fft_Rh07R01 = []
for k in np.arange(0,len(signal_Rh07R01),1):
    num1 = abs(np.fft.rfft(signal_Rh07R01[k]))
    fft_Rh07R01.append(num1)

# %%
fft_dfall = []
for k in np.arange(0,len(fft_Rh07R01),1):
    fft_df=pd.DataFrame(fft_Rh07R01[k])
    fft_dfall.append(fft_df)

# %%
fft_dfall = []
for k in np.arange(0,len(fft_Rh07R01),1):
    fft_df=pd.DataFrame(fft_Rh07R01[k])
    fft_dfall.append(fft_df)
fft_Finalall = []
for j in np.arange(0,len(fft_Rh07R01),1):
    fft_Final = fft_dfall[j].iloc[0:251]
    fft_Finalall.append(fft_Final)

# %%
fft_Finalall = []
for j in np.arange(0,len(fft_Rh07R01),1):
    fft_Final = fft_dfall[j].iloc[0:251]
    fft_Finalall.append(fft_Final)

# %%
path = r'fft_Run01_Rh7_0/'
for j in np.arange(0,len(fft_Rh07R01),1):
    num2 = pd.DataFrame(fft_Finalall[j])
    num2.to_csv(path + f"fft_Rh7Run01_{j}.csv")

# %%
td_all = pd.concat(dfs, ignore_index=True)

# %%
td_all
# Out:
#            Time   Data
# 0      1170.000  0.273
# 1      1170.050  0.276
# 2      1170.100  0.205
# 3      1170.150  0.164
# 4      1170.200  0.102
# ...         ...    ...
# 29416  1239.804  1.047
# 29417  1239.854  1.028
# 29418  1239.904  1.048
# 29419  1239.954  1.074
# 29420  1240.004  1.090
#
# [29421 rows x 2 columns]

# %%
time = dfs[0]['Time'].to_numpy()

# %%
signal_td = dfs[0]['Data'].to_numpy()

# %%
signal_td
# Out:
# array([0.273, 0.276, 0.205, ..., 1.419, 1.477, 1.542])

# %%
freq = np.fft.rfftfreq(len(time),0.05)

# %%
freq.shape
# Out:
# (701,)

# %%
signal_fd = abs(np.fft.rfft(signal_td))

# %%
signal_fd.shape
# Out:
# (701,)

# %%
df = pd.DataFrame(signal_fd)
df
# Out:
#                   0
# 0      14880.211000
# 1        641.465716
# 2        396.281969
# 3        583.202845
# 4         54.578495
# ...             ...
# 14706      1.142763
# 14707      1.583458
# 14708      3.188668
# 14709      1.937231
# 14710      2.981006
#
# [14711 rows x 1 columns]

# %%
df.to_csv("fft_dataRh7.csv")

# %% [markdown]
# ### Bg Rh7

# %%
dfBg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run01_Rh7_0/bg_Rh7_0/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
dfBg
# Out:
#           Time     Data
# 0     1170.000   -0.014
# 1     1170.050   -0.023
# 2     1170.100   -0.028
# 3     1170.150    0.018
# 4     1170.200    0.008
# 5     1170.250   -0.006
# 6     1170.300    0.005
# 7     1170.350    0.005
# 8     1170.400   -0.001
# 9     1170.450   -0.008
# 10    1170.500   -0.014
# 11    1170.550   -0.001
# 12    1170.600   -0.014
# 13    1170.650    0.009
# 14    1170.700    0.005
# 15    1170.750   -0.007
# 16    1170.800    0.004
# 17    1170.850    0.014
# 18    1170.900    0.013
# 19    1170.950    0.032
# 20    1171.000    0.016
# 21    1171.050   -0.007
# 22    1171.100    0.018
# 23    1171.150   -0.004
# 24    1171.200    0.005
# 25    1171.250    0.040
# 26    1171.300    0.011
# 27    1171.350    0.007
# 28    1171.400    0.020
# 29    1171.450    0.012
# 30    1171.500    0.041
# 31    1171.550    0.039
# 32    1171.600    0.037
# 33    1171.650    0.044
# 34    1171.700    0.053
# 35    1171.750    0.020
# 36    1171.800    0.040
# ...

# %%
time_Rh7 = dfBg['Time'].to_numpy()
signal_td_Rh7 = dfBg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh7),0.05)
signal_bg_Rh7 = abs(np.fft.rfft(signal_td_Rh7))

# %%
signal_bg_Rh7.shape
# Out:
# (701,)

# %%
df1 = pd.DataFrame(signal_bg_Rh7)
df1
# Out:
#                0
# 0     579.243000
# 1     397.549084
# 2     325.792320
# 3     538.539027
# 4     384.546107
# 5     433.096709
# 6     123.034410
# 7     780.130756
# 8     644.628409
# 9    2287.693023
# 10   1355.999285
# 11   1378.088284
# 12   1809.926586
# 13   2511.917593
# 14   3540.948357
# 15   3620.498011
# 16   4277.726103
# 17   4195.567445
# 18   4651.796829
# 19   5183.006130
# 20   5164.678737
# 21   5420.810601
# 22   5192.706409
# 23   5778.326023
# 24   5643.092551
# 25   5638.382414
# 26   5760.426992
# 27   5725.374474
# 28   5660.921584
# 29   5592.299839
# 30   5529.586775
# 31   5234.318105
# 32   5330.904505
# 33   5119.162626
# 34   5324.709390
# 35   5384.096818
# 36   5497.560732
# 37   5097.248066
# 38   5237.062421
# 39   4759.564730
# 40   5028.240594
# 41   4951.289657
# 42   5093.170058
# 43   5014.912858
# 44   4859.732862
# 45   4608.859618
# 46   4515.045520
# 47   4335.006465
# 48   4156.513882
# 49   4060.319896
# 50   3986.811516
# ...

# %%
df1.to_csv("Bg_Rh7.csv")

# %% [markdown]
# # Rh6

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run02_Rh6_5/'
filenames = glob.glob(path + "td*.csv")

dfs_R02 = []
for filename in filenames:
    dfs_R02.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_5R02 = []
for i in np.arange(0,len(dfs_R02),1):
    num = dfs_R02[i]['Data'].to_numpy()
    signal_Rh06_5R02.append(num)
fft_Rh06_5 = []
for k in np.arange(0,len(signal_Rh06_5R02),1):
    num1 = abs(np.fft.rfft(signal_Rh06_5R02[k]))
    fft_Rh06_5.append(num1)
fft_R02 = []
for k in np.arange(0,len(fft_Rh06_5),1):
    fft_df=pd.DataFrame(fft_Rh06_5[k])
    fft_dfall.append(fft_R02)
fft_FinalR02 = []
for j in np.arange(0,len(fft_Rh06_5),1):
    fft_Final = fft_dfall[j].iloc[0:251]
    fft_FinalR02.append(fft_Final)
path = r'fft_Run02_Rh6_5/'
for j in np.arange(0,len(fft_Rh06_5),1):
    num2 = pd.DataFrame(fft_FinalR02[j])
    num2.to_csv(path + f"fft_Rh6_5Run02_{j}.csv")

# %%
time_Rh6 = Rh6_data['Time'].to_numpy()
signal_td_Rh6 = Rh6_data['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6),0.05)
signal_data_Rh6 = abs(np.fft.rfft(signal_td_Rh6))

# %%
df2 = pd.DataFrame(signal_data_Rh6)
df2
# Out:
#                   0
# 0      15380.882000
# 1        866.076350
# 2        565.056837
# 3        546.092920
# 4        130.787703
# ...             ...
# 14706      1.006037
# 14707      1.774027
# 14708      1.719795
# 14709      3.733500
# 14710      3.362736
#
# [14711 rows x 1 columns]

# %%
df2.to_csv("fft_dataRh6.csv")

# %% [markdown]
# ### Bg Rh6

# %%
df6Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run02_Rh6_5/bg_Rh6_5/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6Bg
# Out:
#           Time     Data
# 0     1170.000   -0.035
# 1     1170.050    0.002
# 2     1170.100   -0.014
# 3     1170.150   -0.007
# 4     1170.200   -0.004
# 5     1170.250    0.028
# 6     1170.300    0.000
# 7     1170.350    0.012
# 8     1170.400    0.040
# 9     1170.450    0.016
# 10    1170.500    0.014
# 11    1170.550   -0.017
# 12    1170.600    0.020
# 13    1170.650    0.046
# 14    1170.700   -0.029
# 15    1170.750   -0.013
# 16    1170.800    0.016
# 17    1170.850   -0.028
# 18    1170.900   -0.011
# 19    1170.950   -0.035
# 20    1171.000    0.006
# 21    1171.050    0.017
# 22    1171.100    0.013
# 23    1171.150    0.030
# 24    1171.200    0.027
# 25    1171.250    0.025
# 26    1171.300    0.019
# 27    1171.350    0.022
# 28    1171.400    0.052
# 29    1171.450    0.027
# 30    1171.500    0.070
# 31    1171.550    0.049
# 32    1171.600    0.073
# 33    1171.650    0.048
# 34    1171.700    0.061
# 35    1171.750    0.059
# 36    1171.800    0.088
# ...

# %%
time_Rh6 = df6Bg['Time'].to_numpy()
signal_td_Rh6 = df6Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6),0.05)
signal_bg_Rh6 = abs(np.fft.rfft(signal_td_Rh6))

# %%
df3 = pd.DataFrame(signal_bg_Rh6)
df3
# Out:
#                0
# 0     559.458000
# 1     402.937255
# 2     332.330718
# 3     536.663480
# 4     376.324842
# 5     431.771872
# 6     120.848299
# 7     774.748990
# 8     641.825359
# 9    2269.099682
# 10   1339.939727
# 11   1368.163656
# 12   1801.206477
# 13   2495.146077
# 14   3519.757698
# 15   3599.688441
# 16   4257.525598
# 17   4176.328483
# 18   4631.502702
# 19   5162.564296
# 20   5139.779111
# 21   5401.189651
# 22   5173.044341
# 23   5758.019262
# 24   5623.510209
# 25   5622.055393
# 26   5745.029043
# 27   5711.771299
# 28   5646.686977
# 29   5576.708303
# 30   5515.093445
# 31   5225.013144
# 32   5319.804863
# 33   5112.896430
# 34   5318.896357
# 35   5380.906245
# 36   5490.856504
# 37   5094.472519
# 38   5240.028211
# 39   4793.796756
# 40   5033.496912
# 41   4957.302239
# 42   5101.460191
# 43   5024.406605
# 44   4870.648078
# 45   4619.597524
# 46   4529.862894
# 47   4349.724428
# 48   4172.910953
# 49   4074.152901
# 50   4000.943769
# ...

# %%
df3.to_csv("Bg_Rh6.csv")

# %% [markdown]
# # Rh5_7

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run03_Rh5_7/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh05_7R03 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh05_7R03.append(num)
fft_Rh05_7_R03 = []
for k in np.arange(0,len(signal_Rh05_7R03),1):
    num1 = abs(np.fft.rfft(signal_Rh05_7R03[k]))
    fft_Rh05_7_R03.append(num1)
path = r'fft_Run03_Rh5_7/'
for j in np.arange(0,len(fft_Rh05_7_R03),1):
    num2 = pd.DataFrame(fft_Rh05_7_R03[j])
    num2.to_csv(path + f"fft_Rh5_7Run03_{j}.csv")

# %%
time_Rh5 = dfBg['Time'].to_numpy()
signal_td_Rh5 = dfBg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh5),0.05)
signal_data_Rh5 = abs(np.fft.rfft(signal_td_Rh7))

# %%
df_Rh5 = pd.DataFrame(signal_data_Rh5)
df_Rh5
# Out:
#                0
# 0     579.243000
# 1     397.549084
# 2     325.792320
# 3     538.539027
# 4     384.546107
# 5     433.096709
# 6     123.034410
# 7     780.130756
# 8     644.628409
# 9    2287.693023
# 10   1355.999285
# 11   1378.088284
# 12   1809.926586
# 13   2511.917593
# 14   3540.948357
# 15   3620.498011
# 16   4277.726103
# 17   4195.567445
# 18   4651.796829
# 19   5183.006130
# 20   5164.678737
# 21   5420.810601
# 22   5192.706409
# 23   5778.326023
# 24   5643.092551
# 25   5638.382414
# 26   5760.426992
# 27   5725.374474
# 28   5660.921584
# 29   5592.299839
# 30   5529.586775
# 31   5234.318105
# 32   5330.904505
# 33   5119.162626
# 34   5324.709390
# 35   5384.096818
# 36   5497.560732
# 37   5097.248066
# 38   5237.062421
# 39   4759.564730
# 40   5028.240594
# 41   4951.289657
# 42   5093.170058
# 43   5014.912858
# 44   4859.732862
# 45   4608.859618
# 46   4515.045520
# 47   4335.006465
# 48   4156.513882
# 49   4060.319896
# 50   3986.811516
# ...

# %%
df_Rh5.to_csv("fft_dataRh5_7.csv")

# %% [markdown]
# ### BgRh5_7

# %%
df5_7Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run03_Rh5_7/bg_Rh5_7/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df5_7Bg
# Out:
#           Time     Data
# 0     1170.000   -0.015
# 1     1170.050   -0.013
# 2     1170.100   -0.046
# 3     1170.150   -0.027
# 4     1170.200   -0.036
# 5     1170.250   -0.027
# 6     1170.300    0.015
# 7     1170.350   -0.005
# 8     1170.400   -0.005
# 9     1170.450   -0.005
# 10    1170.500    0.020
# 11    1170.550    0.009
# 12    1170.600    0.027
# 13    1170.650    0.027
# 14    1170.700    0.043
# 15    1170.750    0.008
# 16    1170.800    0.025
# 17    1170.850    0.006
# 18    1170.900   -0.004
# 19    1170.950    0.004
# 20    1171.000    0.031
# 21    1171.050   -0.010
# 22    1171.100    0.019
# 23    1171.150   -0.017
# 24    1171.200    0.012
# 25    1171.250   -0.002
# 26    1171.300    0.012
# 27    1171.350    0.003
# 28    1171.400    0.015
# 29    1171.450    0.035
# 30    1171.500    0.031
# 31    1171.550    0.014
# 32    1171.600    0.007
# 33    1171.650    0.016
# 34    1171.700    0.018
# 35    1171.750    0.038
# 36    1171.800    0.060
# ...

# %%
time_Rh5_7 = df5_7Bg['Time'].to_numpy()
signal_td_Rh5_7 = df5_7Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh5_7),0.05)
signal_data_Rh5_7 = abs(np.fft.rfft(signal_td_Rh5_7))

# %%
df5_7 = pd.DataFrame(signal_data_Rh5_7)
df5_7.to_csv("Bg_Rh5_7.csv")

# %% [markdown]
# # Rh5_5

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run04_Rh5_5/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh05_5R04 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh05_5R04.append(num)
fft_Rh05_5_R04 = []
for k in np.arange(0,len(signal_Rh05_5R04),1):
    num1 = abs(np.fft.rfft(signal_Rh05_5R04[k]))
    fft_Rh05_5_R04.append(num1)
path = r'fft_Run04_Rh5_5/'
for j in np.arange(0,len(fft_Rh05_5_R04),1):
    num2 = pd.DataFrame(fft_Rh05_5_R04[j])
    num2.to_csv(path + f"fft_Rh5_5Run04_{j}.csv")

# %%
time_Rh5_5 = Rh5_5data['Time'].to_numpy()
signal_td_Rh5_5 = Rh5_5data['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh5_5),0.05)
signal_data_Rh5_5 = abs(np.fft.rfft(signal_td_Rh5_5))

# %%
df_Rh5_5 = pd.DataFrame(signal_data_Rh5_5)
df_Rh5_5.to_csv("fft_dataRh5_5.csv")

# %% [markdown]
# ### BgRh5_5

# %%
df5_5Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run04_Rh5_5/bg_Rh5_5/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df5_5Bg
# Out:
#           Time     Data
# 0     1170.000   -0.034
# 1     1170.050   -0.036
# 2     1170.100   -0.012
# 3     1170.150   -0.026
# 4     1170.200   -0.018
# 5     1170.250   -0.019
# 6     1170.300   -0.012
# 7     1170.350   -0.017
# 8     1170.400   -0.000
# 9     1170.450    0.004
# 10    1170.500    0.004
# 11    1170.550    0.023
# 12    1170.600    0.009
# 13    1170.650    0.005
# 14    1170.700    0.029
# 15    1170.750    0.024
# 16    1170.800    0.005
# 17    1170.850    0.025
# 18    1170.900    0.030
# 19    1170.950    0.016
# 20    1171.000   -0.002
# 21    1171.050    0.014
# 22    1171.100    0.011
# 23    1171.150    0.039
# 24    1171.200    0.037
# 25    1171.250    0.016
# 26    1171.300    0.012
# 27    1171.350    0.053
# 28    1171.400    0.046
# 29    1171.450    0.024
# 30    1171.500    0.055
# 31    1171.550    0.043
# 32    1171.600    0.043
# 33    1171.650    0.049
# 34    1171.700    0.065
# 35    1171.750    0.069
# 36    1171.800    0.066
# ...

# %%
time_Rh5_5 = df5_5Bg['Time'].to_numpy()
signal_td_Rh5_5 = df5_5Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh5_5),0.05)
signal_data_Rh5_5 = abs(np.fft.rfft(signal_td_Rh5_5))

# %%
df5_5 = pd.DataFrame(signal_data_Rh5_5)
df5_5.to_csv("Bg_Rh5_5.csv")

# %% [markdown]
# # Rh6_0R05

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run05_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R05 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R05.append(num)
fft_Rh06_0_R05 = []
for k in np.arange(0,len(signal_Rh06_0R05),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R05[k]))
    fft_Rh06_0_R05.append(num1)
path = r'fft_Run05_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R05),1):
    num2 = pd.DataFrame(fft_Rh06_0_R05[j])
    num2.to_csv(path + f"fft_Rh6_0Run05_{j}.csv")

# %%
Rh6_0R05 = pd.concat(dfs, ignore_index=True)
Rh6_0R05
# Out:
#            Time   Data
# 0      1170.000  0.296
# 1      1170.050  0.245
# 2      1170.100  0.180
# 3      1170.150  0.152
# 4      1170.200  0.101
# ...         ...    ...
# 29416  1239.804  1.004
# 29417  1239.854  1.026
# 29418  1239.904  1.011
# 29419  1239.954  1.047
# 29420  1240.004  1.040
#
# [29421 rows x 2 columns]

# %%
time_Rh6_0 = Rh6_0R05['Time'].to_numpy()
signal_td_Rh6_0 = Rh6_0R05['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_data_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfRh6_0 = pd.DataFrame(signal_data_Rh6_0)
dfRh6_0.to_csv("fft_dataRh6_0R05.csv")

# %% [markdown]
# ## BgRh6_0R05

# %%
df6_0Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run05_Rh6_0/bg_Rh6_0/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0Bg
# Out:
#           Time     Data
# 0     1170.000   -0.040
# 1     1170.050   -0.013
# 2     1170.100   -0.018
# 3     1170.150   -0.009
# 4     1170.200   -0.018
# 5     1170.250   -0.010
# 6     1170.300    0.002
# 7     1170.350    0.019
# 8     1170.400   -0.005
# 9     1170.450   -0.003
# 10    1170.500    0.015
# 11    1170.550    0.007
# 12    1170.600    0.016
# 13    1170.650    0.011
# 14    1170.700   -0.005
# 15    1170.750   -0.000
# 16    1170.800    0.018
# 17    1170.850    0.029
# 18    1170.900   -0.006
# 19    1170.950    0.010
# 20    1171.000    0.025
# 21    1171.050    0.024
# 22    1171.100    0.010
# 23    1171.150    0.017
# 24    1171.200    0.042
# 25    1171.250    0.023
# 26    1171.300    0.047
# 27    1171.350    0.039
# 28    1171.400    0.050
# 29    1171.450    0.047
# 30    1171.500    0.050
# 31    1171.550    0.047
# 32    1171.600    0.053
# 33    1171.650    0.070
# 34    1171.700    0.075
# 35    1171.750    0.095
# 36    1171.800    0.077
# ...

# %%
time_Rh6_0 = df6_0Bg['Time'].to_numpy()
signal_td_Rh6_0 = df6_0Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_data_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfBg_Rh6_0 = pd.DataFrame(signal_data_Rh6_0)
dfBg_Rh6_0.to_csv("Bg_Rh6_0R05.csv")

# %% [markdown]
# # Rh7_0R06

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run06_Rh7_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh07_0R06 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh07_0R06.append(num)
fft_Rh07_0_R06 = []
for k in np.arange(0,len(signal_Rh07_0R06),1):
    num1 = abs(np.fft.rfft(signal_Rh07_0R06[k]))
    fft_Rh07_0_R06.append(num1)
path = r'fft_Run06_Rh7_0/'
for j in np.arange(0,len(fft_Rh07_0_R06),1):
    num2 = pd.DataFrame(fft_Rh07_0_R06[j])
    num2.to_csv(path + f"fft_Rh7_0Run06_{j}.csv")

# %%
time_Rh7_0 = Rh7_0R06['Time'].to_numpy()
signal_td_Rh7_0 = Rh7_0R06['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh7_0),0.05)
signal_data_Rh7_0 = abs(np.fft.rfft(signal_td_Rh7_0))

# %%
dfRh7_0R06 = pd.DataFrame(signal_data_Rh7_0)
dfRh7_0R06.to_csv("fft_dataRh7_0R06.csv")

# %% [markdown]
# ### BgRh7_0R06

# %%
df7_0Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run06_Rh7_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df7_0Bg
# Out:
#           Time     Data
# 0     1170.000   -0.011
# 1     1170.050   -0.015
# 2     1170.100    0.009
# 3     1170.150   -0.000
# 4     1170.200   -0.007
# 5     1170.250   -0.005
# 6     1170.300   -0.001
# 7     1170.350    0.010
# 8     1170.400    0.004
# 9     1170.450   -0.007
# 10    1170.500    0.003
# 11    1170.550    0.015
# 12    1170.600   -0.001
# 13    1170.650    0.001
# 14    1170.700   -0.003
# 15    1170.750   -0.009
# 16    1170.800   -0.012
# 17    1170.850    0.008
# 18    1170.900    0.013
# 19    1170.950    0.010
# 20    1171.000   -0.004
# 21    1171.050    0.011
# 22    1171.100    0.044
# 23    1171.150    0.029
# 24    1171.200    0.037
# 25    1171.250    0.051
# 26    1171.300    0.031
# 27    1171.350    0.046
# 28    1171.400    0.031
# 29    1171.450    0.035
# 30    1171.500    0.037
# 31    1171.550    0.023
# 32    1171.600    0.039
# 33    1171.650    0.051
# 34    1171.700    0.038
# 35    1171.750    0.018
# 36    1171.800    0.002
# ...

# %%
time_Rh7_0 = df7_0Bg['Time'].to_numpy()
signal_td_Rh7_0 = df7_0Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh7_0),0.05)
signal_Bg_Rh7_0 = abs(np.fft.rfft(signal_td_Rh7_0))

# %%
dfBg_Rh7_0 = pd.DataFrame(signal_data_Rh7_0)
dfBg_Rh7_0.to_csv("Bg_Rh7_0R06.csv")

# %% [markdown]
# # Rh6_0R07

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run07_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R07 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R07.append(num)
fft_Rh06_0_R07 = []
for k in np.arange(0,len(signal_Rh06_0R07),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R07[k]))
    fft_Rh06_0_R07.append(num1)
path = r'fft_Run07_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R07),1):
    num2 = pd.DataFrame(fft_Rh06_0_R07[j])
    num2.to_csv(path + f"fft_Rh6_0Run07_{j}.csv")

# %%
time_Rh6_0 = Rh6_0R07['Time'].to_numpy()
signal_td_Rh6_0 = Rh6_0R07['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_data_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfRh6_0 = pd.DataFrame(signal_data_Rh6_0)
dfRh6_0.to_csv("fft_dataRh6_0R07.csv")

# %% [markdown]
# ### BgRh6_0R07

# %%
df6_0Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run07_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0Bg
# Out:
#           Time     Data
# 0     1170.000    0.010
# 1     1170.050    0.045
# 2     1170.100    0.012
# 3     1170.150    0.011
# 4     1170.200   -0.006
# 5     1170.250   -0.015
# 6     1170.300    0.002
# 7     1170.350   -0.007
# 8     1170.400   -0.003
# 9     1170.450   -0.007
# 10    1170.500    0.006
# 11    1170.550    0.001
# 12    1170.600    0.017
# 13    1170.650    0.003
# 14    1170.700   -0.008
# 15    1170.750    0.008
# 16    1170.800   -0.035
# 17    1170.850   -0.014
# 18    1170.900   -0.002
# 19    1170.950   -0.018
# 20    1171.000   -0.013
# 21    1171.050    0.007
# 22    1171.100    0.005
# 23    1171.150    0.005
# 24    1171.200    0.007
# 25    1171.250    0.040
# 26    1171.300    0.028
# 27    1171.350    0.039
# 28    1171.400    0.034
# 29    1171.450    0.038
# 30    1171.500    0.050
# 31    1171.550    0.039
# 32    1171.600    0.020
# 33    1171.650    0.026
# 34    1171.700    0.006
# 35    1171.750    0.029
# 36    1171.800    0.009
# ...

# %%
time_Rh6_0 = df6_0Bg['Time'].to_numpy()
signal_td_Rh6_0 = df6_0Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_Bg_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfBg_Rh6_0 = pd.DataFrame(signal_Bg_Rh6_0)
dfBg_Rh6_0.to_csv("Bg_Rh6_0R07.csv")

# %% [markdown]
# # Rh6_0R08

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run08_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R08 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R08.append(num)
fft_Rh06_0_R08 = []
for k in np.arange(0,len(signal_Rh06_0R08),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R08[k]))
    fft_Rh06_0_R08.append(num1)
path = r'fft_Run08_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R08),1):
    num2 = pd.DataFrame(fft_Rh06_0_R08[j])
    num2.to_csv(path + f"fft_Rh6_0Run08_{j}.csv")

# %%
time_Rh6_0 = Rh6_0R08['Time'].to_numpy()
signal_td_Rh6_0 = Rh6_0R08['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_data_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfRh6_0R08 = pd.DataFrame(signal_data_Rh6_0)
dfRh6_0R08.to_csv("fft_dataRh6_0R08.csv")

# %% [markdown]
# ## BgRh6_0R08

# %%
df6_0Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run08_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0Bg
# Out:
#           Time     Data
# 0     1170.000   -0.026
# 1     1170.050   -0.015
# 2     1170.100   -0.021
# 3     1170.150    0.005
# 4     1170.200   -0.009
# 5     1170.250   -0.010
# 6     1170.300   -0.041
# 7     1170.350   -0.019
# 8     1170.400   -0.016
# 9     1170.450   -0.020
# 10    1170.500   -0.011
# 11    1170.550   -0.007
# 12    1170.600    0.005
# 13    1170.650    0.018
# 14    1170.700    0.005
# 15    1170.750    0.029
# 16    1170.800    0.025
# 17    1170.850    0.019
# 18    1170.900    0.053
# 19    1170.950    0.035
# 20    1171.000    0.046
# 21    1171.050    0.044
# 22    1171.100    0.042
# 23    1171.150    0.046
# 24    1171.200    0.008
# 25    1171.250    0.030
# 26    1171.300    0.020
# 27    1171.350    0.016
# 28    1171.400    0.027
# 29    1171.450    0.015
# 30    1171.500    0.008
# 31    1171.550    0.036
# 32    1171.600   -0.001
# 33    1171.650    0.013
# 34    1171.700    0.030
# 35    1171.750    0.032
# 36    1171.800    0.051
# ...

# %%
time_Rh6_0 = df6_0Bg['Time'].to_numpy()
signal_td_Rh6_0 = df6_0Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_Bg_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfBg_Rh6_0 = pd.DataFrame(signal_Bg_Rh6_0)
dfBg_Rh6_0.to_csv("Bg_Rh6_0R08.csv")

# %% [markdown]
# # Rh6_0R09

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run09_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R09 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R09.append(num)
fft_Rh06_0_R09 = []
for k in np.arange(0,len(signal_Rh06_0R09),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R09[k]))
    fft_Rh06_0_R09.append(num1)
path = r'fft_Run09_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R09),1):
    num2 = pd.DataFrame(fft_Rh06_0_R09[j])
    num2.to_csv(path + f"fft_Rh6_0Run09_{j}.csv")

# %%
time_Rh6_0 = Rh6_0R09['Time'].to_numpy()
signal_td_Rh6_0 = Rh6_0R09['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_data_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfRh6_0R09 = pd.DataFrame(signal_data_Rh6_0)
dfRh6_0R09.to_csv("fft_dataRh6_0R09.csv")

# %% [markdown]
# ### BgRh6_0R09

# %%
df6_0Bg = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run09_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0Bg
# Out:
#           Time     Data
# 0     1170.000   -0.030
# 1     1170.050   -0.040
# 2     1170.100   -0.044
# 3     1170.150   -0.001
# 4     1170.200   -0.031
# 5     1170.250   -0.010
# 6     1170.300   -0.011
# 7     1170.350   -0.020
# 8     1170.400   -0.013
# 9     1170.450   -0.010
# 10    1170.500   -0.008
# 11    1170.550    0.008
# 12    1170.600    0.011
# 13    1170.650    0.032
# 14    1170.700    0.033
# 15    1170.750    0.021
# 16    1170.800    0.024
# 17    1170.850    0.032
# 18    1170.900    0.031
# 19    1170.950    0.026
# 20    1171.000    0.033
# 21    1171.050    0.032
# 22    1171.100    0.034
# 23    1171.150    0.023
# 24    1171.200    0.017
# 25    1171.250    0.022
# 26    1171.300    0.032
# 27    1171.350    0.028
# 28    1171.400    0.055
# 29    1171.450    0.051
# 30    1171.500    0.031
# 31    1171.550    0.019
# 32    1171.600    0.013
# 33    1171.650   -0.002
# 34    1171.700    0.027
# 35    1171.750    0.030
# 36    1171.800    0.037
# ...

# %%
time_Rh6_0 = df6_0Bg['Time'].to_numpy()
signal_td_Rh6_0 = df6_0Bg['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0),0.05)
signal_Bg_Rh6_0 = abs(np.fft.rfft(signal_td_Rh6_0))

# %%
dfBg_Rh6_0 = pd.DataFrame(signal_Bg_Rh6_0)
dfBg_Rh6_0.to_csv("Bg_Rh6_0R09.csv")

# %% [markdown]
# # Rh6_0R10

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run10_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R10 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R10.append(num)
fft_Rh06_0_R10 = []
for k in np.arange(0,len(signal_Rh06_0R10),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R10[k]))
    fft_Rh06_0_R10.append(num1)
path = r'fft_Run10_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R10),1):
    num2 = pd.DataFrame(fft_Rh06_0_R10[j])
    num2.to_csv(path + f"fft_Rh6_0Run10_{j}.csv")

# %%
time_Rh6_0R10 = Rh6_0R10['Time'].to_numpy()
signal_td_Rh6_0R10 = Rh6_0R10['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R10),0.05)
signal_data_Rh6_0R10 = abs(np.fft.rfft(signal_td_Rh6_0R10))

# %%
dfRh6_0R10 = pd.DataFrame(signal_data_Rh6_0R10)
dfRh6_0R10.to_csv("fft_dataRh6_0R10.csv")

# %% [markdown]
# ### BgRh6_0R10

# %%
df6_0BgR10 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run10_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR10
# Out:
#           Time     Data
# 0     1170.000   -0.029
# 1     1170.050   -0.025
# 2     1170.100   -0.007
# 3     1170.150   -0.039
# 4     1170.200    0.014
# 5     1170.250   -0.009
# 6     1170.300    0.025
# 7     1170.350    0.007
# 8     1170.400    0.003
# 9     1170.450    0.020
# 10    1170.500    0.020
# 11    1170.550    0.010
# 12    1170.600    0.022
# 13    1170.650    0.009
# 14    1170.700    0.001
# 15    1170.750    0.000
# 16    1170.800    0.017
# 17    1170.850   -0.001
# 18    1170.900   -0.030
# 19    1170.950   -0.009
# 20    1171.000    0.010
# 21    1171.050   -0.016
# 22    1171.100   -0.015
# 23    1171.150   -0.011
# 24    1171.200    0.010
# 25    1171.250    0.003
# 26    1171.300    0.015
# 27    1171.350   -0.025
# 28    1171.400   -0.007
# 29    1171.450    0.002
# 30    1171.500   -0.030
# 31    1171.550    0.001
# 32    1171.600   -0.023
# 33    1171.650   -0.055
# 34    1171.700   -0.059
# 35    1171.750   -0.030
# 36    1171.800   -0.031
# ...

# %%
time_Rh6_0R10 = df6_0BgR10['Time'].to_numpy()
signal_td_Rh6_0R10 = df6_0BgR10['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R10),0.05)
signal_Bg_Rh6_0R10 = abs(np.fft.rfft(signal_td_Rh6_0R10))

# %%
dfBg_Rh6_0R10 = pd.DataFrame(signal_Bg_Rh6_0R10)
dfBg_Rh6_0R10.to_csv("Bg_Rh6_0R10.csv")

# %% [markdown]
# # Rh6_0R11

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run11_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R11 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R11.append(num)
fft_Rh06_0_R11 = []
for k in np.arange(0,len(signal_Rh06_0R11),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R11[k]))
    fft_Rh06_0_R11.append(num1)
path = r'fft_Run11_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R11),1):
    num2 = pd.DataFrame(fft_Rh06_0_R11[j])
    num2.to_csv(path + f"fft_Rh6_0Run11_{j}.csv")

# %%
time_Rh6_0R11 = Rh6_0R11['Time'].to_numpy()
signal_td_Rh6_0R11 = Rh6_0R11['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R11),0.05)
signal_data_Rh6_0R11 = abs(np.fft.rfft(signal_td_Rh6_0R11))

# %%
dfRh6_0R11 = pd.DataFrame(signal_data_Rh6_0R11)
dfRh6_0R11.to_csv("fft_dataRh6_0R11.csv")

# %% [markdown]
# ### BgRh6_0R11

# %%
df6_0BgR11 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run11_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR11
# Out:
#           Time     Data
# 0     1170.000   -0.031
# 1     1170.050   -0.018
# 2     1170.100   -0.014
# 3     1170.150    0.001
# 4     1170.200   -0.009
# 5     1170.250   -0.010
# 6     1170.300    0.007
# 7     1170.350   -0.003
# 8     1170.400    0.018
# 9     1170.450    0.029
# 10    1170.500    0.005
# 11    1170.550    0.023
# 12    1170.600   -0.004
# 13    1170.650   -0.003
# 14    1170.700    0.002
# 15    1170.750    0.009
# 16    1170.800    0.010
# 17    1170.850   -0.005
# 18    1170.900   -0.008
# 19    1170.950    0.001
# 20    1171.000    0.006
# 21    1171.050    0.010
# 22    1171.100    0.006
# 23    1171.150    0.009
# 24    1171.200    0.021
# 25    1171.250    0.017
# 26    1171.300   -0.003
# 27    1171.350   -0.006
# 28    1171.400   -0.008
# 29    1171.450    0.013
# 30    1171.500    0.006
# 31    1171.550    0.008
# 32    1171.600   -0.002
# 33    1171.650    0.001
# 34    1171.700    0.001
# 35    1171.750   -0.011
# 36    1171.800   -0.025
# ...

# %%
time_Rh6_0R11 = df6_0BgR11['Time'].to_numpy()
signal_td_Rh6_0R11 = df6_0BgR11['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R11),0.05)
signal_Bg_Rh6_0R11 = abs(np.fft.rfft(signal_td_Rh6_0R11))

# %%
dfBg_Rh6_0R11 = pd.DataFrame(signal_Bg_Rh6_0R11)
dfBg_Rh6_0R11.to_csv("Bg_Rh6_0R11.csv")

# %% [markdown]
# # Rh6_0R12

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run12_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R12 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R12.append(num)
fft_Rh06_0_R12 = []
for k in np.arange(0,len(signal_Rh06_0R12),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R12[k]))
    fft_Rh06_0_R12.append(num1)
path = r'fft_Run12_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R12),1):
    num2 = pd.DataFrame(fft_Rh06_0_R12[j])
    num2.to_csv(path + f"fft_Rh6_0Run12_{j}.csv")

# %%
time_Rh6_0R12 = Rh6_0R12['Time'].to_numpy()
signal_td_Rh6_0R12 = Rh6_0R12['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R12),0.05)
signal_data_Rh6_0R12 = abs(np.fft.rfft(signal_td_Rh6_0R12))

# %%
dfRh6_0R12 = pd.DataFrame(signal_data_Rh6_0R12)
dfRh6_0R12.to_csv("fft_dataRh6_0R12.csv")

# %% [markdown]
# ### BgRh6_0R12

# %%
df6_0BgR12 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run12_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR12
# Out:
#           Time     Data
# 0     1170.000    0.031
# 1     1170.050   -0.029
# 2     1170.100   -0.008
# 3     1170.150   -0.024
# 4     1170.200   -0.021
# 5     1170.250   -0.000
# 6     1170.300   -0.007
# 7     1170.350    0.001
# 8     1170.400   -0.012
# 9     1170.450   -0.035
# 10    1170.500   -0.021
# 11    1170.550    0.007
# 12    1170.600   -0.025
# 13    1170.650    0.037
# 14    1170.700    0.023
# 15    1170.750    0.026
# 16    1170.800    0.021
# 17    1170.850    0.046
# 18    1170.900    0.001
# 19    1170.950   -0.013
# 20    1171.000   -0.015
# 21    1171.050    0.000
# 22    1171.100    0.009
# 23    1171.150    0.021
# 24    1171.200    0.004
# 25    1171.250    0.018
# 26    1171.300    0.030
# 27    1171.350    0.027
# 28    1171.400    0.043
# 29    1171.450    0.040
# 30    1171.500    0.042
# 31    1171.550    0.054
# 32    1171.600    0.068
# 33    1171.650    0.046
# 34    1171.700    0.042
# 35    1171.750    0.051
# 36    1171.800    0.050
# ...

# %%
time_Rh6_0R12 = df6_0BgR12['Time'].to_numpy()
signal_td_Rh6_0R12 = df6_0BgR12['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R12),0.05)
signal_Bg_Rh6_0R12 = abs(np.fft.rfft(signal_td_Rh6_0R12))

# %%
dfBg_Rh6_0R12 = pd.DataFrame(signal_Bg_Rh6_0R12)
dfBg_Rh6_0R12.to_csv("Bg_Rh6_0R12.csv")

# %% [markdown]
# # Rh6_0R13

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run13_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R13 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R13.append(num)
fft_Rh06_0_R13 = []
for k in np.arange(0,len(signal_Rh06_0R13),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R13[k]))
    fft_Rh06_0_R13.append(num1)
path = r'fft_Run13_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R13),1):
    num2 = pd.DataFrame(fft_Rh06_0_R13[j])
    num2.to_csv(path + f"fft_Rh6_0Run13_{j}.csv")

# %%
time_Rh6_0R13 = Rh6_0R13['Time'].to_numpy()
signal_td_Rh6_0R13 = Rh6_0R13['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R13),0.05)
signal_data_Rh6_0R13 = abs(np.fft.rfft(signal_td_Rh6_0R13))

# %%
dfRh6_0R13 = pd.DataFrame(signal_data_Rh6_0R13)
dfRh6_0R13.to_csv("fft_dataRh6_0R13.csv")

# %% [markdown]
# ### BgRh6_0R13

# %%
df6_0BgR13 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run13_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR13
# Out:
#           Time     Data
# 0     1170.000   -0.018
# 1     1170.050    0.011
# 2     1170.100   -0.014
# 3     1170.150    0.009
# 4     1170.200   -0.017
# 5     1170.250    0.002
# 6     1170.300    0.001
# 7     1170.350    0.035
# 8     1170.400   -0.006
# 9     1170.450   -0.012
# 10    1170.500    0.004
# 11    1170.550   -0.020
# 12    1170.600    0.004
# 13    1170.650   -0.010
# 14    1170.700   -0.010
# 15    1170.750    0.007
# 16    1170.800    0.012
# 17    1170.850    0.027
# 18    1170.900    0.013
# 19    1170.950   -0.019
# 20    1171.000   -0.002
# 21    1171.050    0.027
# 22    1171.100    0.022
# 23    1171.150   -0.011
# 24    1171.200    0.009
# 25    1171.250    0.023
# 26    1171.300    0.004
# 27    1171.350    0.030
# 28    1171.400    0.028
# 29    1171.450    0.022
# 30    1171.500    0.022
# 31    1171.550    0.004
# 32    1171.600    0.011
# 33    1171.650    0.021
# 34    1171.700    0.010
# 35    1171.750   -0.004
# 36    1171.800    0.023
# ...

# %%
time_Rh6_0R13 = df6_0BgR13['Time'].to_numpy()
signal_td_Rh6_0R13 = df6_0BgR13['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R13),0.05)
signal_Bg_Rh6_0R13 = abs(np.fft.rfft(signal_td_Rh6_0R13))

# %%
dfBg_Rh6_0R13 = pd.DataFrame(signal_Bg_Rh6_0R13)
dfBg_Rh6_0R13.to_csv("Bg_Rh6_0R13.csv")

# %% [markdown]
# # Rh6_0R14

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run14_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R14 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R14.append(num)
fft_Rh06_0_R14 = []
for k in np.arange(0,len(signal_Rh06_0R14),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R14[k]))
    fft_Rh06_0_R14.append(num1)
path = r'fft_Run14_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R14),1):
    num2 = pd.DataFrame(fft_Rh06_0_R14[j])
    num2.to_csv(path + f"fft_Rh6_0Run14_{j}.csv")

# %%
time_Rh6_0R14 = Rh6_0R14['Time'].to_numpy()
signal_td_Rh6_0R14 = Rh6_0R14['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R14),0.05)
signal_data_Rh6_0R14 = abs(np.fft.rfft(signal_td_Rh6_0R14))

# %%
dfRh6_0R14 = pd.DataFrame(signal_data_Rh6_0R14)
dfRh6_0R14.to_csv("fft_dataRh6_0R14.csv")

# %% [markdown]
# ### BgRh6_0R14

# %%
df6_0BgR14 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run14_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR14
# Out:
#           Time     Data
# 0     1170.000   -0.022
# 1     1170.050   -0.021
# 2     1170.100   -0.021
# 3     1170.150   -0.035
# 4     1170.200    0.010
# 5     1170.250    0.021
# 6     1170.300    0.021
# 7     1170.350    0.014
# 8     1170.400    0.025
# 9     1170.450   -0.028
# 10    1170.500   -0.020
# 11    1170.550   -0.007
# 12    1170.600    0.042
# 13    1170.650    0.006
# 14    1170.700   -0.035
# 15    1170.750    0.017
# 16    1170.800   -0.014
# 17    1170.850    0.021
# 18    1170.900    0.000
# 19    1170.950    0.027
# 20    1171.000    0.015
# 21    1171.050    0.017
# 22    1171.100    0.035
# 23    1171.150    0.036
# 24    1171.200    0.020
# 25    1171.250    0.044
# 26    1171.300    0.036
# 27    1171.350    0.080
# 28    1171.400    0.040
# 29    1171.450    0.060
# 30    1171.500    0.040
# 31    1171.550    0.060
# 32    1171.600    0.034
# 33    1171.650    0.050
# 34    1171.700    0.048
# 35    1171.750    0.019
# 36    1171.800    0.024
# ...

# %%
time_Rh6_0R14 = df6_0BgR14['Time'].to_numpy()
signal_td_Rh6_0R14 = df6_0BgR14['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R14),0.05)
signal_Bg_Rh6_0R14 = abs(np.fft.rfft(signal_td_Rh6_0R14))

# %%
dfBg_Rh6_0R14 = pd.DataFrame(signal_Bg_Rh6_0R14)
dfBg_Rh6_0R14.to_csv("Bg_Rh6_0R14.csv")

# %% [markdown]
# # Rh6_0R15

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run15_Rh6_0/'
filenames = glob.glob(path + "td*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename,sep = ',', encoding='utf-8', names=['Time','Data']))

# %%
signal_Rh06_0R15 = []
for i in np.arange(0,len(dfs),1):
    num = dfs[i]['Data'].to_numpy()
    signal_Rh06_0R15.append(num)
fft_Rh06_0_R15 = []
for k in np.arange(0,len(signal_Rh06_0R15),1):
    num1 = abs(np.fft.rfft(signal_Rh06_0R15[k]))
    fft_Rh06_0_R15.append(num1)
path = r'fft_Run15_Rh6_0/'
for j in np.arange(0,len(fft_Rh06_0_R15),1):
    num2 = pd.DataFrame(fft_Rh06_0_R15[j])
    num2.to_csv(path + f"fft_Rh6_0Run15_{j}.csv")

# %%
time_Rh6_0R15 = Rh6_0R15['Time'].to_numpy()
signal_td_Rh6_0R15 = Rh6_0R15['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R15),0.05)
signal_data_Rh6_0R15 = abs(np.fft.rfft(signal_td_Rh6_0R15))

# %%
dfRh6_0R15 = pd.DataFrame(signal_data_Rh6_0R15)
dfRh6_0R15.to_csv("fft_dataRh6_0R15.csv")

# %% [markdown]
# ### BgRh6_0R15

# %%
df6_0BgR15 = pd.read_csv("C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/RS211014_Run15_Rh6_0/bg/td-0-0.csv",sep = ',', encoding='utf-8', names=['Time','Data'])
df6_0BgR15
# Out:
#           Time     Data
# 0     1170.000   -0.038
# 1     1170.050   -0.038
# 2     1170.100   -0.005
# 3     1170.150   -0.006
# 4     1170.200    0.001
# 5     1170.250   -0.023
# 6     1170.300   -0.015
# 7     1170.350    0.017
# 8     1170.400    0.021
# 9     1170.450    0.013
# 10    1170.500    0.015
# 11    1170.550    0.017
# 12    1170.600    0.005
# 13    1170.650   -0.002
# 14    1170.700   -0.007
# 15    1170.750    0.002
# 16    1170.800   -0.006
# 17    1170.850    0.016
# 18    1170.900   -0.001
# 19    1170.950    0.033
# 20    1171.000   -0.000
# 21    1171.050    0.020
# 22    1171.100    0.020
# 23    1171.150    0.030
# 24    1171.200    0.022
# 25    1171.250    0.023
# 26    1171.300    0.035
# 27    1171.350    0.016
# 28    1171.400    0.046
# 29    1171.450    0.032
# 30    1171.500    0.018
# 31    1171.550    0.025
# 32    1171.600    0.004
# 33    1171.650    0.019
# 34    1171.700    0.031
# 35    1171.750    0.043
# 36    1171.800    0.054
# ...

# %%
time_Rh6_0R15 = df6_0BgR15['Time'].to_numpy()
signal_td_Rh6_0R15 = df6_0BgR15['Data'].to_numpy()
freq = np.fft.rfftfreq(len(time_Rh6_0R15),0.05)
signal_Bg_Rh6_0R15 = abs(np.fft.rfft(signal_td_Rh6_0R15))

# %%
dfBg_Rh6_0R15 = pd.DataFrame(signal_Bg_Rh6_0R15)
dfBg_Rh6_0R15.to_csv("Bg_Rh6_0R15.csv")
