# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from PIL import Image
import rampy
from BaselineRemoval import BaselineRemoval
# %matplotlib inline
# %config InlineBackend.figure_fornat = 'retina'
pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',5000)

# %% [markdown]
# ## Run01

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run01_Rh7_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run01 = []
for file in filenames:
    dfs_Run01.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run01 = pd.read_csv("Bg_Rh7_0R01.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Bg_Run01
# Out:
#             Data
# 0     579.243000
# 1     397.549084
# 2     325.792320
# 3     538.539027
# 4     384.546107
# 5     433.096709
# 6     123.034410
# 7     780.130756
# 8     644.628409
# 9    2287.693023
# 10   1355.999285
# 11   1378.088284
# 12   1809.926586
# 13   2511.917593
# 14   3540.948357
# 15   3620.498011
# 16   4277.726103
# 17   4195.567445
# 18   4651.796829
# 19   5183.006130
# 20   5164.678737
# 21   5420.810601
# 22   5192.706409
# 23   5778.326023
# 24   5643.092551
# 25   5638.382414
# 26   5760.426992
# 27   5725.374474
# 28   5660.921584
# 29   5592.299839
# 30   5529.586775
# 31   5234.318105
# 32   5330.904505
# 33   5119.162626
# 34   5324.709390
# 35   5384.096818
# 36   5497.560732
# 37   5097.248066
# 38   5237.062421
# 39   4759.564730
# 40   5028.240594
# 41   4951.289657
# 42   5093.170058
# 43   5014.912858
# 44   4859.732862
# 45   4608.859618
# 46   4515.045520
# 47   4335.006465
# 48   4156.513882
# 49   4060.319896
# 50   3986.811516
# ...

# %%
dfs_Run01[0]
# Out:
#             Data
# 0     458.668000
# 1     356.436481
# 2     383.745505
# 3     432.626133
# 4     512.111809
# 5     624.775104
# 6     316.369882
# 7     453.089436
# 8     341.627428
# 9    1896.438256
# 10   1502.684323
# 11   2056.973794
# 12   1654.129917
# 13   1896.630396
# 14   3175.195034
# 15   3711.341235
# 16   4652.921793
# 17   4197.700737
# 18   4160.596094
# 19   4592.358971
# 20   4887.725271
# 21   5426.658683
# 22   5178.384631
# 23   5578.898952
# 24   5329.936522
# 25   5391.924284
# 26   5586.316369
# 27   5531.336603
# 28   5361.098600
# 29   5199.544841
# 30   5177.046897
# 31   5072.923896
# 32   5323.145837
# 33   5094.577535
# 34   5139.550704
# 35   5033.895097
# 36   5066.254267
# 37   4753.779471
# 38   5023.533241
# 39   4716.115578
# 40   5005.077027
# 41   4873.149696
# 42   4894.712837
# 43   4695.756315
# 44   4494.861532
# 45   4287.990692
# 46   4286.409291
# 47   4216.535909
# 48   4096.566936
# 49   3967.046769
# 50   3806.940701
# ...

# %%
Nor_Run01 = []
for i in np.arange(0,len(dfs_Run01),1):
    cal_Run01 =np.sqrt(dfs_Run01[i]**2+10)/np.sqrt(dfs_Run01[1]**2+10)
    Nor_Run01.append(cal_Run01)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run01),1):
    df = pd.DataFrame(Nor_Run01[j])
    df.to_csv(path + f"Nor_Run01_{j}.csv")

# %%
Nor_Run01[0]
# Out:
#           Data
# 0     0.791941
# 1     0.896685
# 2     1.177984
# 3     0.803433
# 4     1.331831
# 5     1.442677
# 6     2.571494
# 7     0.580887
# 8     0.530060
# 9     0.829074
# 10    1.108275
# 11    1.492729
# 12    0.914021
# 13    0.755153
# 14    0.896808
# 15    1.025191
# 16    1.087809
# 17    1.000608
# 18    0.894506
# 19    0.886142
# 20    0.946475
# 21    1.001179
# 22    0.997342
# 23    0.965587
# 24    0.944606
# 25    0.956389
# 26    0.969875
# 27    0.966209
# 28    0.947136
# 29    0.929869
# 30    0.936345
# 31    0.969266
# 32    0.998645
# 33    0.995297
# 34    0.965327
# 35    0.935056
# 36    0.921646
# 37    0.932717
# 38    0.959327
# 39    0.990971
# 40    0.995493
# 41    0.984318
# 42    0.961135
# 43    0.936459
# 44    0.925019
# 45    0.930480
# 46    0.949461
# 47    0.972771
# 48    0.985678
# 49    0.977128
# 50    0.954984
# 51    0.930745
# 52    0.919433
# 53    0.926829
# 54    0.943738
# 55    0.966548
# 56    0.979098
# ...

# %%
Nor_Run01[0]
# Out:
#           Data
# 0     0.791840
# 1     0.896585
# 2     1.177884
# 3     0.803333
# 4     1.331731
# 5     1.442576
# 6     2.571394
# 7     0.580787
# 8     0.529960
# 9     0.828974
# 10    1.108175
# 11    1.492628
# 12    0.913921
# 13    0.755053
# 14    0.896708
# 15    1.025091
# 16    1.087709
# 17    1.000508
# 18    0.894406
# 19    0.886042
# 20    0.946375
# 21    1.001079
# 22    0.997242
# 23    0.965487
# 24    0.944506
# 25    0.956289
# 26    0.969775
# 27    0.966109
# 28    0.947036
# 29    0.929769
# 30    0.936245
# 31    0.969166
# 32    0.998545
# 33    0.995197
# 34    0.965227
# 35    0.934956
# 36    0.921546
# 37    0.932617
# 38    0.959227
# 39    0.990871
# 40    0.995393
# 41    0.984218
# 42    0.961035
# 43    0.936359
# 44    0.924919
# 45    0.930380
# 46    0.949361
# 47    0.972671
# 48    0.985578
# 49    0.977028
# 50    0.954884
# 51    0.930645
# 52    0.919333
# 53    0.926729
# 54    0.943638
# 55    0.966448
# 56    0.978998
# ...

# %% [markdown]
# ## Run02

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run02_Rh6_5/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run02 = []
for file in filenames:
    dfs_Run02.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run02 = pd.read_csv("Bg_Rh6_5.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run02 = []
for i in np.arange(0,len(dfs_Run02),1):
    cal_Run02 =np.sqrt(dfs_Run02[i]**2 + 10)/np.sqrt(dfs_Run02[1]**2 + 10)
    Nor_Run02.append(cal_Run02)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run02),1):
    df = pd.DataFrame(Nor_Run02[j])
    df.to_csv(path + f"Nor_Run02_{j}.csv")

# %% [markdown]
# ## Run03

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run03_Rh5_7/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run03 = []
for file in filenames:
    dfs_Run03.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run03 = pd.read_csv("Bg_Rh5_7.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run03 = []
for i in np.arange(0,len(dfs_Run03),1):
    cal_Run03 = np.sqrt(dfs_Run03[i]**2 + 10)/np.sqrt(dfs_Run03[1]**2 + 10)
    Nor_Run03.append(cal_Run03)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run03),1):
    df = pd.DataFrame(Nor_Run03[j])
    df.to_csv(path + f"Nor_Run03_{j}.csv")

# %% [markdown]
# ## Run04

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run04_Rh5_5/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run04 = []
for file in filenames:
    dfs_Run04.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run04 = pd.read_csv("Bg_Rh5_5.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run04 = []
for i in np.arange(0,len(dfs_Run04),1):
    cal_Run04 = np.sqrt(dfs_Run04[i]**2 + 10)/np.sqrt(dfs_Run04[1]**2 + 10)
    Nor_Run04.append(cal_Run04)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run04),1):
    df = pd.DataFrame(Nor_Run04[j])
    df.to_csv(path + f"Nor_Run04_{j}.csv")

# %% [markdown]
# ## Run05

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run05_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run05 = []
for file in filenames:
    dfs_Run05.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run05 = pd.read_csv("Bg_Rh6_0R05.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run05 = []
for i in np.arange(0,len(dfs_Run05),1):
    cal_Run05 = np.sqrt(dfs_Run05[i]**2 + 10)/np.sqrt(dfs_Run05[1]**2 + 10)
    Nor_Run05.append(cal_Run05)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run05),1):
    df = pd.DataFrame(Nor_Run05[j])
    df.to_csv(path + f"Nor_Run05_{j}.csv")

# %% [markdown]
# ## Run06

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run06_Rh7_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run06 = []
for file in filenames:
    dfs_Run06.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run06 = pd.read_csv("Bg_Rh7_0R06.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run06 = []
for i in np.arange(0,len(dfs_Run06),1):
    cal_Run06 = np.sqrt(dfs_Run06[i]**2 + 10)/np.sqrt(dfs_Run06[1]**2 + 10)
    Nor_Run06.append(cal_Run06)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run06),1):
    df = pd.DataFrame(Nor_Run06[j])
    df.to_csv(path + f"Nor_Run06_{j}.csv")

# %% [markdown]
# ## Run07

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run07_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run07 = []
for file in filenames:
    dfs_Run07.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run07 = pd.read_csv("Bg_Rh6_0R07.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run07 = []
for i in np.arange(0,len(dfs_Run07),1):
    cal_Run07 = np.sqrt(dfs_Run07[i]**2 + 10)/np.sqrt(dfs_Run07[1]**2 + 10)
    Nor_Run07.append(cal_Run07)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run07),1):
    df = pd.DataFrame(Nor_Run07[j])
    df.to_csv(path + f"Nor_Run07_{j}.csv")

# %% [markdown]
# ## Run08

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run08_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run08 = []
for file in filenames:
    dfs_Run08.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run08 = pd.read_csv("Bg_Rh6_0R08.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run08 = []
for i in np.arange(0,len(dfs_Run08),1):
    cal_Run08 = np.sqrt(dfs_Run08[i]**2 + 10)/np.sqrt(dfs_Run08[1]**2 + 10)
    Nor_Run08.append(cal_Run08)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run08),1):
    df = pd.DataFrame(Nor_Run08[j])
    df.to_csv(path + f"Nor_Run08_{j}.csv")

# %% [markdown]
# ## Run09

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run09_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run09 = []
for file in filenames:
    dfs_Run09.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run09 = pd.read_csv("Bg_Rh6_0R09.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run09 = []
for i in np.arange(0,len(dfs_Run09),1):
    cal_Run09 = np.sqrt(dfs_Run09[i]**2 + 10)/np.sqrt(dfs_Run09[1]**2 + 10)
    Nor_Run09.append(cal_Run09)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run09),1):
    df = pd.DataFrame(Nor_Run09[j])
    df.to_csv(path + f"Nor_Run09_{j}.csv")

# %% [markdown]
# ## Run10

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run10_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run10 = []
for file in filenames:
    dfs_Run10.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run10 = pd.read_csv("Bg_Rh6_0R10.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run10 = []
for i in np.arange(0,len(dfs_Run10),1):
    cal_Run10 = np.sqrt(dfs_Run10[i]**2 + 10)/np.sqrt(dfs_Run10[1]**2 + 10)
    Nor_Run10.append(cal_Run10)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run10),1):
    df = pd.DataFrame(Nor_Run10[j])
    df.to_csv(path + f"Nor_Run10_{j}.csv")

# %% [markdown]
# ## Run11

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run11_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run11 = []
for file in filenames:
    dfs_Run11.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run11 = pd.read_csv("Bg_Rh6_0R11.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run11 = []
for i in np.arange(0,len(dfs_Run11),1):
    cal_Run11 = np.sqrt(dfs_Run11[i]**2 + 10)/np.sqrt(dfs_Run11[1]**2 + 10)
    Nor_Run11.append(cal_Run11)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run11),1):
    df = pd.DataFrame(Nor_Run11[j])
    df.to_csv(path + f"Nor_Run11_{j}.csv")

# %% [markdown]
# ## Run12

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run12_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run12 = []
for file in filenames:
    dfs_Run12.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run12 = pd.read_csv("Bg_Rh6_0R12.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run12 = []
for i in np.arange(0,len(dfs_Run12),1):
    cal_Run12 = np.sqrt(dfs_Run11[i]**2 + 10)/np.sqrt(dfs_Run11[1]**2 + 10)
    Nor_Run12.append(cal_Run12)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run12),1):
    df = pd.DataFrame(Nor_Run12[j])
    df.to_csv(path + f"Nor_Run12_{j}.csv")

# %% [markdown]
# ## Run13

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run13_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run13 = []
for file in filenames:
    dfs_Run13.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run13 = pd.read_csv("Bg_Rh6_0R13.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run13 = []
for i in np.arange(0,len(dfs_Run13),1):
    cal_Run13 = np.sqrt(dfs_Run13[i]**2 + 10)/np.sqrt(dfs_Run13[1]**2 + 10)
    Nor_Run13.append(cal_Run13)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run13),1):
    df = pd.DataFrame(Nor_Run13[j])
    df.to_csv(path + f"Nor_Run13_{j}.csv")

# %% [markdown]
# ## Run14

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run14_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run14 = []
for file in filenames:
    dfs_Run14.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run14 = pd.read_csv("Bg_Rh6_0R14.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run14 = []
for i in np.arange(0,len(dfs_Run14),1):
    cal_Run14 = np.sqrt(dfs_Run14[i]**2 + 10)/np.sqrt(dfs_Run14[1]**2 + 10)
    Nor_Run14.append(cal_Run14)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run14),1):
    df = pd.DataFrame(Nor_Run14[j])
    df.to_csv(path + f"Nor_Run14_{j}.csv")

# %% [markdown]
# ## Run15

# %%
import glob
path =r'C:/Users/HP/Desktop/Data/DataAnalysis_raman/NewDatasetTHz/fft_Run15_Rh6_0/'
filenames = glob.glob(path + "fft*.csv")

dfs_Run15 = []
for file in filenames:
    dfs_Run15.append(pd.read_csv(file,sep = ',', encoding='utf-8', names=['Data'], skiprows=1))

# %%
Bg_Run15 = pd.read_csv("Bg_Rh6_0R15.csv",sep = ',', encoding='utf-8', names=['Data'], skiprows=1)

# %%
Nor_Run15 = []
for i in np.arange(0,len(dfs_Run15),1):
    cal_Run15 = np.sqrt(dfs_Run15[i]**2 + 10)/np.sqrt(dfs_Run15[1]**2 + 10)
    Nor_Run15.append(cal_Run15)
path = r'Nor_all/'
for j in np.arange(0,len(Nor_Run15),1):
    df = pd.DataFrame(Nor_Run15[j])
    df.to_csv(path + f"Nor_Run15_{j}.csv")
